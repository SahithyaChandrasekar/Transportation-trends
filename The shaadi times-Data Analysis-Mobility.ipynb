# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('F:/New folder/world_mobility_with_covid_infection_count.csv')
dx=df
dx.columns
# Out:
# Index(['COUNTRY_REGION_CODE', 'COUNTRY_REGION', 'DATE_VAL', 'DAY_CT',
#        'RETAIL_AND_RECREATION_PCT', 'INC_RETAIL_AND_RECREATION_PCT',
#        'GROCERY_AND_PHARMACY_PCT', 'INC_GROCERY_AND_PHARMACY_PCT', 'PARKS_PCT',
#        'INC_PARKS_PCT', 'TRANSIT_STATIONS_PCT', 'INC_TRANSIT_STATIONS_PCT',
#        'WORKPLACES_PCT', 'INC_WORKPLACES_PCT', 'RESIDENTIAL_PCT',
#        'INC_RESIDENTIAL_PCT', 'COVID_CONFIRMED', 'COVID_RECOVERED',
#        'COVID_DEATHS', 'COVID_CNTY_NEW_CASES', 'COVID_COUNTRY_INC_RATE',
#        'COVID_COUNTRY_RECOVR_INC_RATE', 'COVID_COUNTRY_DEATH_INC_RATE',
#        'COVID_WORLD_CONFIRMED', 'COVID_WORLD_RECOVERED', 'COVID_WORLD_DEATHS',
#        'COVID_WORLD_INC_RATE', 'COVID_WORLD_RECVR_INC_RATE',
#        'COVID_WORLD_DEATH_INC_RATE'],
#       dtype='object')

# %%
#comparing india v/s world mobility
df=df[(df['COUNTRY_REGION']=='India')]#load india dataset
plt.style.use('seaborn-darkgrid')
my_dpi=96
plt.figure(figsize=(480/my_dpi, 480/my_dpi), dpi=my_dpi)
dx.dropna()
x=pd.DataFrame(dx.dtypes)
lst=[]
for r in x.itertuples():
    if r[1]!='object':
        lst.append(r[0])
dx.dropna()
collist=['RETAIL_AND_RECREATION_PCT','GROCERY_AND_PHARMACY_PCT','PARKS_PCT']
#average on world data
dfavg=dx.groupby(['DAY_CT']).mean()
dfavg.reset_index(inplace=True)

# %%
plt.rcParams["figure.figsize"] = (15,8)
#GROCERY_AND_PHARMACY
plt.plot(dfavg['DAY_CT'], dfavg['GROCERY_AND_PHARMACY_PCT'], marker='', color='orange', linewidth=3, alpha=0.7)
plt.title("Grocery and Pharmacy", loc='left', fontsize=12, fontweight=0, color='blue')
plt.xlabel("Day Count")
plt.ylabel("GROCERY AND PHARMACY Percentage")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-750e0435e657> in <module>
#       8 plt.xlabel("Day Count")
#       9 plt.ylabel("GROCERY AND PHARMACY_PCT Percentage")
# ---> 10 fig = plt.get_figure()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'get_figure'

# %%
plt.plot(dfavg['DAY_CT'], dfavg['WORKPLACES_PCT'], marker='', color='orange', linewidth=3, alpha=0.7)
plt.title("Workplaces", loc='left', fontsize=12, fontweight=0, color='blue')
plt.xlabel("Day Count")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %%
#PARKS
plt.plot(dfavg['DAY_CT'], dfavg['PARKS_PCT'], marker='', color='orange', linewidth=3, alpha=0.7)
plt.title("Parks", loc='left', fontsize=12, fontweight=0, color='blue')
plt.xlabel("Day Count")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %%
#TRANSIT STATIONS
plt.plot(dfavg['DAY_CT'], dfavg['TRANSIT_STATIONS_PCT'], marker='', color='orange', linewidth=3, alpha=0.7)
plt.title("Transit Stations", loc='left', fontsize=12, fontweight=0, color='blue')
plt.xlabel("Day Count")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %%
#Covid-19 increase rate 
x='COVID_COUNTRY_INC_RATE'
plt.plot(dfavg['DAY_CT'], dfavg['COVID_COUNTRY_INC_RATE'], marker='', color='orange', linewidth=3, alpha=0.7)
plt.xlabel("Day Count")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %%
#COVID_NEW_CASES
x='COVID_CNTY_NEW_CASES'
plt.plot(dfavg['DAY_CT'], dfavg['COVID_CNTY_NEW_CASES'], marker='', color='orange', linewidth=3, alpha=0.7)
plt.xlabel("Day Count")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %%
lst_params=['RETAIL_AND_RECREATION_PCT','GROCERY_AND_PHARMACY_PCT','PARKS_PCT','TRANSIT_STATIONS_PCT','WORKPLACES_PCT','RESIDENTIAL_PCT']
for x in lst_params:
    plt.plot(dfavg['DAY_CT'], dfavg[x], color='orange', linewidth=3, alpha=0.6)
    plt.text(57.7, dfavg[x].tail(1),'World '+x,horizontalalignment='left',size='large' ,color='Orange')
lst = ['COVID_COUNTRY_INC_RATE']
for y in lst:
    plt.plot(dfavg['DAY_CT'], dfavg[y], color='red', linewidth=3, alpha=0.6)
    plt.text(57.7, dfavg[x].tail(1),'World '+x,horizontalalignment='left',size='large' ,color='Orange')
plt.xlabel("Day Count")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')
